# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential

from keras.layers import Dense,Activation,Dropout,Convolution2D, MaxPooling2D, Flatten #flatten是进行扁平化操作
from keras.optimizers import SGD,Adam
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import pydot
import os

os.environ["PATH"] += os.pathsep + 'E:/GV/bin'

# %%
#载入数据
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#[60000,28,28,1] 最后的1维代表图片深度，如果是彩色图片，深度为3
x_train = x_train.reshape(-1,28,28,1) / 255.0 # 做归一化处理
x_test = x_test.reshape(-1,28,28,1) / 255.0
#将标签转换为one_hot编码
y_train = np_utils.to_categorical(y_train, num_classes=10)
y_test = np_utils.to_categorical(y_test, num_classes=10)

# %%
#创建模型


model = Sequential()

##
#input_shape(输入平面)
#filter 滤波器
#kernelsize 卷积窗口
#strides 步长
#padding same/valid

#第一个卷积层
model.add(Convolution2D(
    input_shape = (28,28,1), 
    filters=32,  
    kernel_size=5,
    strides=1,
    padding='same',
    activation='relu'
))
#第一个池化层 池化后图片成为14*14，32个特征图
model.add(MaxPooling2D(
    pool_size=2,
    strides=2,
    padding='same'
))
#第二个卷积层
model.add(Convolution2D(
    #input_shape = (28,28,1), 
    filters=64,  
    kernel_size=5,
    strides=1,
    padding='same',
    activation='relu'
))
#第2个池化层，变成7*7,64个特征图
model.add(MaxPooling2D(
    pool_size=2,
    strides=2,
    padding='same'
))
#扁平化为1维，64*7*7
model.add(Flatten())

#接入全连接网络
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10,activation='softmax'))

adam = Adam(lr=1e-4)




#NN模型
#model = Sequential([
#    Dense(units=200, input_dim=784, bias_initializer='zero',activation='tanh',kernel_regularizer=l2(0.0003)),
#    #Dropout(0.4),
#    Dense(units=200, bias_initializer='zero',activation='tanh',kernel_regularizer=l2(0.0003)),
#    #Dropout(0.4),
#    Dense(units=10,activation='softmax',kernel_regularizer=l2(0.0003))
#])

#sgd = SGD(lr=0.2)
#adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
#将loss改变为交叉熵
model.compile(
    optimizer=adam, 
    loss='categorical_crossentropy',
    #loss = 'mse',
    metrics=['accuracy'])

# %%
plot_model(model,to_file='keras-cnn.png',show_shapes=True,show_layer_names=False,rankdir='TB')
plt.figure(figsize=(10, 10))
img = plt.read('keras-cnn.png')
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Conda3\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# C:\Conda3\lib\site-packages\pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# C:\Conda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...
